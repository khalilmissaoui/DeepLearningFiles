# %%
import pandas as pd
data=pd.read_csv("C:/Users/esprit/Desktop/data/phone_price.csv",header=0,sep =',')

# %%
data.head()
#data.shape
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0            842     0          2.2         0   1       0           7    0.6
# 1           1021     1          0.5         1   0       1          53    0.7
# 2            563     1          0.5         1   2       1          41    0.9
# 3            615     1          2.5         0   0       0          10    0.8
# 4           1821     1          1.2         0  13       1          44    0.6
#
#    mobile_wt  n_cores     ...       px_height  px_width   ram  sc_h  sc_w  \
# 0        188        2     ...              20       756  2549     9     7
# 1        136        3     ...             905      1988  2631    17     3
# 2        145        5     ...            1263      1716  2603    11     2
# 3        131        6     ...            1216      1786  2769    16     8
# 4        141        2     ...            1208      1212  1411     8     2
#
#    talk_time  three_g  touch_screen  wifi  price_range
# ...

# %% [markdown]
# I. Phase d'ajout du bruit au niveau de nos données

# %%
import numpy as np 
mu, sigma = 100, 0.1 
noise = np.random.normal(mu, sigma)
print(noise)
data.iloc[:20,0]=data.iloc[:20,0]+noise
data.iloc[:20,2]=data.iloc[:20,2]+noise
data.iloc[:20,8]=data.iloc[:20,8]+noise
# Out:
# 100.03809550533691

# %%
data.head()
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0     942.038096     0   102.238096         0   1       0           7    0.6
# 1    1121.038096     1   100.538096         1   0       1          53    0.7
# 2     663.038096     1   100.538096         1   2       1          41    0.9
# 3     715.038096     1   102.538096         0   0       0          10    0.8
# 4    1921.038096     1   101.238096         0  13       1          44    0.6
#
#     mobile_wt  n_cores     ...       px_height  px_width   ram  sc_h  sc_w  \
# 0  288.038096        2     ...              20       756  2549     9     7
# 1  236.038096        3     ...             905      1988  2631    17     3
# 2  245.038096        5     ...            1263      1716  2603    11     2
# 3  231.038096        6     ...            1216      1786  2769    16     8
# 4  241.038096        2     ...            1208      1212  1411     8     2
#
# ...

# %% [markdown]
# on essaye d'ajouter des valeurs nulls
# on essaye aussi d'ajouter des valeurs redondantes
# on essaye d'ajouter des valeurs non rationnelles

# %%
#data = data.replace(data.iloc[21:50,0],'null')
import numpy as np
#data['battery_power'] = np.where(data['battery_power']>1000, np.nan,data['battery_power'])
data.iloc[21:50,0] = np.where(data.iloc[21:50,0]>1200, np.nan,data.iloc[21:50,0])
data.head(50)
# Out:
#     battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0      942.038096     0   102.238096         0   1       0           7    0.6
# 1     1121.038096     1   100.538096         1   0       1          53    0.7
# 2      663.038096     1   100.538096         1   2       1          41    0.9
# 3      715.038096     1   102.538096         0   0       0          10    0.8
# 4     1921.038096     1   101.238096         0  13       1          44    0.6
# 5     1959.038096     0   100.538096         1   3       0          22    0.7
# 6     1921.038096     0   101.738096         0   4       1          10    0.8
# 7     2054.038096     0   100.538096         1   0       0          24    0.8
# 8     1545.038096     1   100.538096         0   0       0          53    0.7
# 9      609.038096     1   100.638096         1   2       1           9    0.1
# 10     869.038096     1   102.938096         1   0       0           9    0.1
# ...

# %%
import numpy as np
data['wifi'] = np.where(data['wifi']==0, 'non', 'oui')
#data = data.replace(data.iloc[21:50],'null')
data.head()
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0     942.038096     0   102.238096         0   1       0           7    0.6
# 1    1121.038096     1   100.538096         1   0       1          53    0.7
# 2     663.038096     1   100.538096         1   2       1          41    0.9
# 3     715.038096     1   102.538096         0   0       0          10    0.8
# 4    1921.038096     1   101.238096         0  13       1          44    0.6
#
#     mobile_wt  n_cores     ...      px_height  px_width   ram  sc_h  sc_w  \
# 0  288.038096        2     ...             20       756  2549     9     7
# 1  236.038096        3     ...            905      1988  2631    17     3
# 2  245.038096        5     ...           1263      1716  2603    11     2
# 3  231.038096        6     ...           1216      1786  2769    16     8
# 4  241.038096        2     ...           1208      1212  1411     8     2
#
#    talk_time  three_g  touch_screen  wifi price_range
# ...

# %% [markdown]
# on va enregistrer ce fichier pour l'utiliser dans la phase de préparation des données.

# %%
data.to_csv (r'C:\Users\esprit\Desktop\jupyter notebook\file3.csv', index = False, header=True)

# %% [markdown]
# II. Phase de préparation maintenant

# %%
data.shape # get number of rows and columns
# Out:
# (2000, 21)

# %%
data.info() # additional info about dataframe
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 21 columns):
# battery_power    1985 non-null float64
# blue             2000 non-null int64
# clock_speed      2000 non-null float64
# dual_sim         2000 non-null int64
# fc               2000 non-null int64
# four_g           2000 non-null int64
# int_memory       2000 non-null int64
# m_dep            2000 non-null float64
# mobile_wt        2000 non-null float64
# n_cores          2000 non-null int64
# pc               2000 non-null int64
# px_height        2000 non-null int64
# px_width         2000 non-null int64
# ram              2000 non-null int64
# sc_h             2000 non-null int64
# sc_w             2000 non-null int64
# talk_time        2000 non-null int64
# three_g          2000 non-null int64
# touch_screen     2000 non-null int64
# wifi             2000 non-null object
# price_range      2000 non-null int64
# dtypes: float64(4), int64(16), object(1)
# ...

# %%
data.describe() # statistical description, only for numeric values
# Out:
#        battery_power       blue  clock_speed     dual_sim           fc  \
# count    1985.000000  2000.0000  2000.000000  2000.000000  2000.000000
# mean     1237.120787     0.4950     2.522631     0.509500     4.309500
# std       439.846586     0.5001     9.960214     0.500035     4.341444
# min       501.000000     0.0000     0.500000     0.000000     0.000000
# 25%       852.000000     0.0000     0.700000     0.000000     1.000000
# 50%      1224.000000     0.0000     1.500000     1.000000     3.000000
# 75%      1615.000000     1.0000     2.300000     1.000000     7.000000
# max      2054.038096     1.0000   102.938096     1.000000    19.000000
#
#             four_g   int_memory        m_dep    mobile_wt      n_cores  \
# count  2000.000000  2000.000000  2000.000000  2000.000000  2000.000000
# mean      0.521500    32.046500     0.501750   141.249381     4.520500
# std       0.499662    18.145715     0.288416    37.168378     2.287837
# ...

# %%
import matplotlib.pyplot as plt
data['price_range'].value_counts().plot.pie()
plt.show()

# %% [markdown]
# std: indique la déviation de la réponse par rapport à la moyenne

# %%
data.columns
# Out:
# Index(['battery_power', 'blue', 'clock_speed', 'dual_sim', 'fc', 'four_g',
#        'int_memory', 'm_dep', 'mobile_wt', 'n_cores', 'pc', 'px_height',
#        'px_width', 'ram', 'sc_h', 'sc_w', 'talk_time', 'three_g',
#        'touch_screen', 'wifi', 'price_range'],
#       dtype='object')

# %%
data.head() # show first 5 rows
data.tail() # last 5 rows
data.columns # list all column names
data.shape # get number of rows and columns
data.info() # additional info about dataframe
data.describe() # statistical description, only for numeric values
#data['col_name'].value_counts(dropna=False) # count unique values in a column
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 21 columns):
# battery_power    1985 non-null float64
# blue             2000 non-null int64
# clock_speed      2000 non-null float64
# dual_sim         2000 non-null int64
# fc               2000 non-null int64
# four_g           2000 non-null int64
# int_memory       2000 non-null int64
# m_dep            2000 non-null float64
# mobile_wt        2000 non-null float64
# n_cores          2000 non-null int64
# pc               2000 non-null int64
# px_height        2000 non-null int64
# px_width         2000 non-null int64
# ram              2000 non-null int64
# sc_h             2000 non-null int64
# sc_w             2000 non-null int64
# talk_time        2000 non-null int64
# three_g          2000 non-null int64
# touch_screen     2000 non-null int64
# wifi             2000 non-null object
# price_range      2000 non-null int64
# dtypes: float64(4), int64(16), object(1)
# ...

# %%
data=data.dropna()

# %%
data.shape
# Out:
# (1985, 21)

# %%
boxplot = data.boxplot(column=['mobile_wt'])
import matplotlib.pyplot as plt
plt.show()

# %%
#'battery_power', 'clock_speed',
boxplot = data.boxplot(column=[ 'ram'])
import matplotlib.pyplot as plt
plt.show()

# %%
#'battery_power', 'clock_speed',
boxplot = data.boxplot(column=[ 'battery_power'])
import matplotlib.pyplot as plt
plt.show()

# %%
#'battery_power', 'clock_speed',
boxplot = data.boxplot(column=[ 'clock_speed'])
import matplotlib.pyplot as plt
plt.show()

# %% [markdown]
# on remarque la présence des outliers

# %%
Q1 = data['clock_speed'].quantile(0.25)
Q3 = data['clock_speed'].quantile(0.75)
IQR = Q3 - Q1    #IQR is interquartile range. 

filter1 = (data['clock_speed'] >= Q1 - 1.5 * IQR) & (data['clock_speed'] <= Q3 + 1.5 *IQR)
data=data.loc[filter1]

# %% [markdown]
# on a éliminé les outliers sur la colonne 'clock_speed'

# %%
Q1 = data['mobile_wt'].quantile(0.25)
Q3 = data['mobile_wt'].quantile(0.75)
IQR = Q3 - Q1    #IQR is interquartile range. 

filter2 = (data['mobile_wt'] >= Q1 - 1.5 * IQR) & (data['mobile_wt'] <= Q3 + 1.5 *IQR)
data=data.loc[filter2]

# %%
data.shape
# Out:
# (1965, 21)

# %%
boxplot = data.boxplot(column=[ 'clock_speed','mobile_wt'])
import matplotlib.pyplot as plt
plt.show()

# %%
from sklearn.preprocessing import LabelEncoder
#pour faire les transformation nécessaire au niveau du WIFI : de la qualitative au numérique 0,1
lb_make = LabelEncoder()
data["wifi"] = lb_make.fit_transform(data["wifi"])

# %%
data.head()
# Out:
#     battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 20          772.0     0          1.1         1  12       0          39    0.8
# 24          503.0     0          1.2         1   5       1           8    0.4
# 25          961.0     1          1.4         1   0       1          57    0.6
# 26          519.0     1          1.6         1   7       1          51    0.3
# 27          956.0     0          0.5         0   1       1          41    1.0
#
#     mobile_wt  n_cores     ...       px_height  px_width   ram  sc_h  sc_w  \
# 20       81.0        7     ...            1314      1854  2819    17    15
# 24      111.0        3     ...             201      1245  2583    11     0
# 25      114.0        8     ...             291      1434  2782    18     9
# 26      132.0        4     ...             550       645  3763    16     1
# 27      143.0        7     ...             511      1075  3286    17     8
#
# ...

# %% [markdown]
# je suis en train de visualiser la corrélation existante entre la variable 1 et la variable 2

# %%
# Seaborn visualization library
import seaborn as sns
# Create the default pairplot
 
sns.pairplot(data.iloc[:,1:3])
plt.show()

# %%
#la corrélation entre variable cible(prix) et variable wifi
sns.pairplot(data.iloc[:,-2:])
plt.show()

# %%
#la matrice de corrélation deux à deux
print(data.corr())
# Out:
#                battery_power      blue  clock_speed  dual_sim        fc  \
# battery_power       1.000000  0.014476     0.009675 -0.041527  0.030019
# blue                0.014476  1.000000     0.024222  0.033376  0.003915
# clock_speed         0.009675  0.024222     1.000000  0.002327  0.002940
# dual_sim           -0.041527  0.033376     0.002327  1.000000 -0.027171
# fc                  0.030019  0.003915     0.002940 -0.027171  1.000000
# four_g              0.016503  0.012326    -0.040533  0.000604 -0.021126
# int_memory         -0.007697  0.043178     0.007302 -0.016039 -0.034568
# m_dep               0.032147 -0.001564    -0.011954 -0.017542 -0.002663
# mobile_wt          -0.001669 -0.005108     0.011069 -0.003310  0.024751
# n_cores            -0.027591  0.033459    -0.003710 -0.025321 -0.010663
# pc                  0.029898 -0.014108    -0.001080 -0.016534  0.645665
# px_height           0.017516 -0.010807    -0.009615 -0.021322 -0.009678
# ...

# %% [markdown]
# on va essayer de retrouver les variables qui sont les plus correlés ( qui mènent à la redondance de l'information)

# %%
def get_redundant_pairs(df):
    '''Get diagonal and lower triangular pairs of correlation matrix'''
    pairs_to_drop = set()
    cols = df.columns
    for i in range(0, df.shape[1]):
        for j in range(0, i+1):
            pairs_to_drop.add((cols[i], cols[j]))
    return pairs_to_drop

def get_top_abs_correlations(df, n=5):
    au_corr = df.corr().abs().unstack()
    labels_to_drop = get_redundant_pairs(df)
    au_corr = au_corr.drop(labels=labels_to_drop).sort_values(ascending=False)
    return au_corr[0:n]

print("Top Absolute Correlations")
print(get_top_abs_correlations(data, 3))
# Out:
# Top Absolute Correlations
# ram     price_range    0.916277
# fc      pc             0.645665
# four_g  three_g        0.586916
# dtype: float64

# %% [markdown]
# on peut faire le meme traitement mais par rapport à la variable cilble
